# %%
import pandas as pd
import numpy as np

# %%
#import data from Ethan
all_beer_df = pd.read_csv('data_csv.csv')

#trim data to needed X colums
print(all_beer_df.columns)

all_beer_df.head()
len(all_beer_df)
all_beer_df.describe
# Out:
# Index(['BeerID', 'Name', 'URL', 'Style', 'StyleID', 'Size(L)', 'OG', 'FG',
#        'ABV', 'IBU', 'Color', 'BoilSize', 'BoilTime', 'BoilGravity',
#        'Efficiency', 'MashThickness', 'SugarScale', 'BrewMethod', 'ViewCount',
#        'BrewCount', 'LastUpdated'],
#       dtype='object')
# C:\Users\brbal\AppData\Local\conda\conda\envs\pythondata\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <bound method NDFrame.describe of        BeerID                                          Name  \
# 0           1                             Vanilla Cream Ale
# 1           2                   Southern Tier Pumking clone
# 2           3                   Zombie Dust Clone - EXTRACT
# 3           4                 Zombie Dust Clone - ALL GRAIN
# 4           5               Bakke Brygg Belgisk Blonde 50 l
# ...

# %%
styles_list = all_beer_df[["Style","Color"]]

styles_list.head()
# Out:
#                                 Style  Color
# 0                           Cream Ale   4.83
# 1  Holiday/Winter Special Spiced Beer  15.64
# 2                        American IPA   8.98
# 3                        American IPA   8.50
# 4                   Belgian Blond Ale   4.57

# %%
unique_styles = styles_list.drop_duplicates(subset="Style")
unique_styles.reset_index(inplace=True, drop=True)
print(len(unique_styles))
# Out:
# 176

# %%
unique_styles.sort_values("Color", ascending=False)
# Out:
#                               Style  Color
# 175        Specialty Wood-Aged Beer  50.00
# 73                   Imperial Stout  50.00
# 27           Russian Imperial Stout  50.00
# 20                    Oatmeal Stout  42.09
# 68              Foreign Extra Stout  40.00
# 21                   Specialty Beer  40.00
# 32                   American Stout  40.00
# 28         Specialty IPA: Black IPA  39.95
# 46                   Wood-Aged Beer  37.22
# 79                    Baltic Porter  36.68
# 165                London Brown Ale  36.46
# 117                     Irish Stout  35.96
# 148               Irish Extra Stout  35.24
# 29                      Sweet Stout  35.08
# 6                     Robust Porter  34.76
# 35                        Dry Stout  31.40
# 14                              NaN  29.40
# 173                  Scottish Light  28.70
# 150        Specialty IPA: Brown IPA  25.29
# 30                Strong Scotch Ale  24.85
# 55                     Brown Porter  24.79
# ...

# %%
unique_styles.to_csv("style_list.csv")

# %%
category_data_all = pd.read_csv("style_category_list.csv", index_col=0, encoding="latin1")

category_data = category_data_all[["Style", "Category"]]

category_data.head()
# Out:
#                         Style          Category
# 27     Russian Imperial Stout  Stouts & Porters
# 73             Imperial Stout  Stouts & Porters
# 175  Specialty Wood-Aged Beer  Stouts & Porters
# 20              Oatmeal Stout  Stouts & Porters
# 21             Specialty Beer  Stouts & Porters

# %%
#look at all beer file
print(len(all_beer_df["Style"]))
all_beer_df.head()
# Out:
# 73861
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  URL  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 Style  StyleID  Size(L)     OG     FG   ABV  \
# 0                           Cream Ale       45    21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 2                        American IPA        7    18.93  1.063  1.018  5.91
# ...

# %%
#setup a for loop 

all_beer_v2 = all_beer_df.merge(category_data,on="Style",how="inner")

# %%
all_beer_v2.head()
# Out:
#    BeerID                                          Name  \
# 0       1                             Vanilla Cream Ale
# 1       8  Spotted Clown (New Glarus Spotted Cow clone)
# 2      43                     Vanilla Caramel Cream Ale
# 3     200                          Cream of Three Crops
# 4     244                       Sleeman Cream Ale Clone
#
#                                                  URL      Style  StyleID  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale  Cream Ale       45
# 1  /homebrew/recipe/view/672/spotted-clown-new-gl...  Cream Ale       45
# 2  /homebrew/recipe/view/5314/vanilla-caramel-cre...  Cream Ale       45
# 3   /homebrew/recipe/view/10545/cream-of-three-crops  Cream Ale       45
# 4  /homebrew/recipe/view/24005/sleeman-cream-ale-...  Cream Ale       45
#
#    Size(L)     OG     FG   ABV    IBU  \
# 0    21.77  1.055  1.013  5.48  17.65
# 1    20.82  1.054  1.014  5.36  19.97
# 2    18.93  1.055  1.014  5.43  33.67
# ...

# %%
print(len(all_beer_v2["Efficiency"]))

boil_test = all_beer_v2["Efficiency"].dropna(how="any")
len(boil_test)
# Out:
# 73861
# 73861

# %%
all_beer_reduced = all_beer_v2.drop(["URL","Size(L)","BoilGravity", "MashThickness", "SugarScale", "BrewMethod"], axis=1)

all_beer_reduced.head()
# Out:
#    BeerID                                          Name      Style  StyleID  \
# 0       1                             Vanilla Cream Ale  Cream Ale       45
# 1       8  Spotted Clown (New Glarus Spotted Cow clone)  Cream Ale       45
# 2      43                     Vanilla Caramel Cream Ale  Cream Ale       45
# 3     200                          Cream of Three Crops  Cream Ale       45
# 4     244                       Sleeman Cream Ale Clone  Cream Ale       45
#
#       OG     FG   ABV    IBU  Color  BoilSize  BoilTime  Efficiency  \
# 0  1.055  1.013  5.48  17.65   4.83     28.39        75        70.0
# 1  1.054  1.014  5.36  19.97   5.94     28.39        75        70.0
# 2  1.055  1.014  5.43  33.67  10.08     15.14        60        70.0
# 3  1.044  1.012  4.15  18.13   2.56     17.03        90        75.0
# 4  1.055  1.015  5.22  19.73   4.74     28.40        60        70.0
#
#    ViewCount  BrewCount                 LastUpdated  \
# ...

# %%
#Output the revised data
all_beer_reduced.to_csv("style_category_toSQL.csv", index=False)

# %%
#check the length of 
print(len(all_beer_reduced))
# Out:
# 73861
