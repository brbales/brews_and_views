# %% [markdown]
# ## Beer Scrape with Pandas

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import pymongo
from splinter import Browser
from selenium import webdriver
import time
from sqlalchemy import create_engine

# %% [markdown]
# ### Read in csv to pandas df

# %%
csv_data = pd.read_csv('CSV/recipeData.csv', encoding='latin1')
csv_data.head()
# Out:
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  URL  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 Style  StyleID  Size(L)     OG     FG   ABV  \
# 0                           Cream Ale       45    21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 2                        American IPA        7    18.93  1.063  1.018  5.91
# 3                        American IPA        7    22.71  1.061  1.017  5.80
# 4                   Belgian Blond Ale       20    50.00  1.060  1.010  6.48
#
#      IBU   ...     BoilGravity  Efficiency  MashThickness        SugarScale  \
# 0  17.65   ...           1.038        70.0            NaN  Specific Gravity
# 1  60.65   ...           1.070        70.0            NaN  Specific Gravity
# 2  59.25   ...             NaN        70.0            NaN  Specific Gravity
# 3  54.48   ...             NaN        70.0            NaN  Specific Gravity
# 4  17.84   ...           1.050        72.0            NaN  Specific Gravity
#
#    BrewMethod  PitchRate PrimaryTemp PrimingMethod   PrimingAmount   UserId
# 0   All Grain        NaN       17.78    corn sugar          4.5 oz    116.0
# 1   All Grain        NaN         NaN           NaN             NaN    955.0
# 2     extract        NaN         NaN           NaN             NaN      NaN
# 3   All Grain        NaN         NaN           NaN             NaN      NaN
# 4   All Grain        NaN       19.00    Sukkerlake  6-7 g sukker/l  18325.0
#
# [5 rows x 23 columns]

# %%
# Drop last five columns 

data = csv_data.drop(['PitchRate', 'PrimaryTemp', 'PrimingMethod', 'PrimingAmount', 'UserId'], axis=1)

pd.to_numeric(data['StyleID'])

# Create empty columns for values to add

data['ViewCount'] = ''
data['BrewCount'] = ''
data['LastUpdated'] = ''

list(data)
# Out:
# ['BeerID',
#  'Name',
#  'URL',
#  'Style',
#  'StyleID',
#  'Size(L)',
#  'OG',
#  'FG',
#  'ABV',
#  'IBU',
#  'Color',
#  'BoilSize',
#  'BoilTime',
#  'BoilGravity',
#  'Efficiency',
#  'MashThickness',
#  'SugarScale',
#  'BrewMethod',
#  'ViewCount',
#  'BrewCount',
#  'LastUpdated']

# %%
# Color Range

max_color = np.nanmax(data.iloc[:, 10].values)
min_color = np.nanmin(data.iloc[:, 10].values)

f'Max Color: {max_color}, Min Color: {min_color}'
# Out:
# 'Max Color: 186.0, Min Color: 0.0'

# %%
# View Count Range

# %%
# Brew Count Range

# %%
data.head()
# Out:
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  URL  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 Style  StyleID  Size(L)     OG     FG   ABV  \
# 0                           Cream Ale       45    21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 2                        American IPA        7    18.93  1.063  1.018  5.91
# 3                        American IPA        7    22.71  1.061  1.017  5.80
# 4                   Belgian Blond Ale       20    50.00  1.060  1.010  6.48
#
#      IBU     ...      BoilSize  BoilTime  BoilGravity  Efficiency  \
# 0  17.65     ...         28.39        75        1.038        70.0
# 1  60.65     ...         24.61        60        1.070        70.0
# 2  59.25     ...         22.71        60          NaN        70.0
# 3  54.48     ...         26.50        60          NaN        70.0
# 4  17.84     ...         60.00        90        1.050        72.0
#
#    MashThickness        SugarScale BrewMethod ViewCount BrewCount LastUpdated
# 0            NaN  Specific Gravity  All Grain
# 1            NaN  Specific Gravity  All Grain
# 2            NaN  Specific Gravity    extract
# 3            NaN  Specific Gravity  All Grain
# 4            NaN  Specific Gravity  All Grain
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Scrape individual beer page
# ### Grab view count, brew count, and Date
# ### Add to dataframe

# %%
# Scrape Setup

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

view_count = {}
brew_count = {}
updated_date = {}

driver = webdriver.Chrome() 

#executable_path = {'executable_path': driver}
browser = Browser('chrome')


for index, row in data.iterrows():
    
    try: 

        url = 'https://www.brewersfriend.com' + row['URL']    

        browser.visit(url)

        # Beautiful Soup Parsing
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')

        dates_scrape = soup.find('div', class_='lastupdated').text

        # View Count
        counts = soup.find('div', class_='lastupdated').find_all('b')

        view_count_str = counts[0].text
        brew_count_str = counts[1].text


        # Split view count to string by space, only keep second list item
        split_view_count = view_count_str.split(' ')
        view_count = int(split_view_count[2])

        # Split brew count to string by space, only keep second list item
        brew_view_count = brew_count_str.split(' ')
        brew_count = int(brew_view_count[2])



        # Add counts to data frame
        data.loc[index, 'ViewCount'] = view_count
        data.loc[index, 'BrewCount'] = brew_count

        # Grab date
        dates_scrape = soup.find('div', class_='lastupdated').text
        split_dates = dates_scrape.split(' ')
        date = split_dates[9]
        data.loc[index, 'LastUpdated'] = date
        
    except:
        pass

# %%
# Convert to datetime

data['LastUpdated'] = pd.to_datetime(data['LastUpdated'], format='%Y-%m-%d')
data
# Out:
#        BeerID                                          Name  \
# 0           1                             Vanilla Cream Ale
# 1           2                   Southern Tier Pumking clone
# 2           3                   Zombie Dust Clone - EXTRACT
# 3           4                 Zombie Dust Clone - ALL GRAIN
# 4           5               Bakke Brygg Belgisk Blonde 50 l
# 5           6                  Sierra Nevada Pale Ale Clone
# 6           7      Russian River Pliny the Elder (original)
# 7           8  Spotted Clown (New Glarus Spotted Cow clone)
# 8           9                      Chocolate Vanilla Porter
# 9          10                            Mango Habanero IPA
# 10         11                     Bakke Brygg HveteIPA 25 L
# 11         12                               Hop Notch Clone
# 12         13                             Racer 5 IPA Clone
# 13         14                     Sam Adams Rebel IPA Clone
# 14         15                                     White IPA
# 15         16                     Pilsner Urquell BYO clone
# 16         17                                  Tank 7 Clone
# 17         18                       Bells two hearted clone
# 18         19                 New Glarus Fat Squirrel Clone
# 19         20            Avg. Perfect Northeast IPA (NEIPA)
# 20         21                        Goose Island IPA Clone
# 21         22               Ballast Point Sculpin Ale Clone
# 22         23                          Brooklyn Sorachi Ace
# 23         24                           Lagunitas IPA Clone
# 24         25       NEIPA Hoppy ( juicy) -  Braumeister 20L
# 25         26                         Dale's Pale Ale Clone
# 26         27                   IPA - Tired Hands Milkshake
# 27         28                    Bakke Brygg Julelager 20 l
# 28         29                                Grapefruit IPA
# 29         30                Bakke Brygg Robust Porter 50 l
# ...       ...                                           ...
# 73831   73832                              SMASH do Caboclo
# 73832   73833               Experimental Nordic Pine Saison
# 73833   73834                             Cascade Cream Ale
# 73834   73835                                        Lobrau
# 73835   73836                                           IPA
# 73836   73837                                       CBR day
# 73837   73838                               Liberty Bay IPA
# 73838   73839                                        Kölsch
# 73839   73840                                        NZ IPA
# 73840   73841                                  Red Cara Ale
# 73841   73842                          Braumeister IPA 200L
# 73842   73843                                          1SES
# 73843   73844                                        MARZEN
# 73844   73845                                 Easy pale ale
# 73845   73846                              Sober as a Judge
# 73846   73847                                Awesome Recipe
# 73847   73848                           Party-Gyle Grisette
# 73848   73849                           Perfect Brewing Red
# 73849   73850                           Golden Slumbers IPA
# 73850   73851                                Mo Honey Wheat
# 73851   73852                                  Blonde Stout
# 73852   73853                                Session Simcoe
# 73853   73854                          Chris ford wheat ipa
# 73854   73855                          X Files American Ale
# 73855   73856                                   Unicorn Pee
# 73856   73857                                 Amber Alfie 2
# 73857   73858                                       Rye IPA
# 73858   73859                                     SK-Kölsch
# 73859   73860                               Flata Rødkløver
# 73860   73861                         Elvis Juice IPA Clone
#
#                                                      URL  \
# 0           /homebrew/recipe/view/1633/vanilla-cream-ale
# 1      /homebrew/recipe/view/16367/southern-tier-pumk...
# 2      /homebrew/recipe/view/5920/zombie-dust-clone-e...
#
# 73841  4.94  238.63     ...        205.00        80        1.045        75.0
# 73842  4.06   32.39     ...         26.50        60        1.033        72.0
# 73843  5.86   23.56     ...         26.50        60        1.041        65.0
# 73844  4.52    0.00     ...         28.39        60        1.034        70.0
# 73845  4.12   46.83     ...         24.61        60        1.035        68.0
# 73846  3.98    0.00     ...          7.57        60        1.101        35.0
# 73847  4.80   31.58     ...         23.44        60        1.030        72.0
# 73848  5.65    0.00     ...         24.61        60        1.044        70.0
# 73849  5.20   97.08     ...         24.61        60        1.038        65.0
# 73850  5.92   35.15     ...         30.28        60        1.038        70.0
# 73851  7.24   52.94     ...         15.14        60        1.105        75.0
# 73852  4.05   36.60     ...         28.50        60        1.028        70.0
# 73853  7.15    0.00     ...         22.71        60        1.060        70.0
# 73854  6.26    0.00     ...         28.39        60        1.042        75.0
# 73855  6.71   49.35     ...         15.14        30        1.098        55.0
# 73856  5.22   39.73     ...         18.00        60        1.060        63.0
# 73857  6.37   59.21     ...         17.00        60        1.034        60.0
# 73858  5.01   25.42     ...         18.00        90        1.041        65.0
# 73859  4.82   25.65     ...         28.00        60        1.043        72.0
# 73860  6.55   57.09     ...         12.00        60        1.056        70.0
#
#        MashThickness        SugarScale    BrewMethod ViewCount BrewCount  \
# 0                NaN  Specific Gravity     All Grain    150484        42
# 1                NaN  Specific Gravity     All Grain    134371        54
# 2                NaN  Specific Gravity       extract    133892       119
# 3                NaN  Specific Gravity     All Grain    134161        91
# 4                NaN  Specific Gravity     All Grain    131887        25
# 5                NaN  Specific Gravity     All Grain    121823       302
# 6                NaN  Specific Gravity     All Grain    121959        28
# 7               1.40  Specific Gravity     All Grain     95189        18
# 8                NaN  Specific Gravity     All Grain     89406        22
# 9                NaN  Specific Gravity     All Grain     81189        24
# 10               NaN  Specific Gravity     All Grain     80405        27
# 11               NaN  Specific Gravity          BIAB     80856        14
# 12               NaN  Specific Gravity     All Grain     80786        10
# 13               NaN  Specific Gravity       extract     80351        21
# 14              1.20  Specific Gravity     All Grain     80711        13
# 15               NaN  Specific Gravity     All Grain     80064         9
# 16               NaN  Specific Gravity          BIAB     80052        12
# 17               NaN  Specific Gravity     All Grain     80089        46
# 18               NaN  Specific Gravity     All Grain     80093        24
# 19              1.25  Specific Gravity     All Grain     75099        65
# 20              1.50  Specific Gravity     All Grain     38450        33
# 21              1.25  Specific Gravity     All Grain     35378        29
# 22               NaN  Specific Gravity     All Grain     34558         2
# 23               NaN  Specific Gravity     All Grain     29043        12
# 24               NaN  Specific Gravity          BIAB     30567        17
# 25               NaN  Specific Gravity     All Grain     19292         6
# 26               NaN  Specific Gravity          BIAB     20708        11
# 27               NaN  Specific Gravity     All Grain     17658         0
# 28              1.30  Specific Gravity     All Grain     18003         2
# 29               NaN  Specific Gravity     All Grain     17255         3
# ...              ...               ...           ...       ...       ...
# 73831           2.60  Specific Gravity     All Grain
# 73832           1.50  Specific Gravity     All Grain
# 73833            NaN  Specific Gravity          BIAB
# 73834           3.00  Specific Gravity     All Grain
# 73835           3.00  Specific Gravity     All Grain
# 73836            NaN  Specific Gravity          BIAB
# 73837           1.25  Specific Gravity     All Grain
# 73838           1.00  Specific Gravity     All Grain
# 73839           1.50  Specific Gravity     All Grain
# 73840           3.10  Specific Gravity     All Grain
# 73841           1.50  Specific Gravity     All Grain
# 73842            NaN  Specific Gravity          BIAB
# 73843            NaN  Specific Gravity          BIAB
# 73844           1.50  Specific Gravity     All Grain
# 73845           1.50  Specific Gravity     All Grain
# 73846            NaN  Specific Gravity       extract
# 73847            NaN  Specific Gravity          BIAB
# 73848           1.25  Specific Gravity     All Grain
# 73849           1.25  Specific Gravity     All Grain
# 73850            NaN  Specific Gravity          BIAB
# 73851            NaN  Specific Gravity  Partial Mash
# 73852           3.00  Specific Gravity     All Grain
# 73853            NaN  Specific Gravity          BIAB
# 73854            NaN  Specific Gravity          BIAB
# 73855            NaN  Specific Gravity  Partial Mash
# 73856           3.00  Specific Gravity     All Grain
# 73857            NaN  Specific Gravity          BIAB
# 73858            NaN  Specific Gravity          BIAB
# 73859            NaN  Specific Gravity     All Grain
# 73860            NaN  Specific Gravity  Partial Mash
#
#       LastUpdated
# 0      2016-06-14
# 1      2018-01-04
# 2      2018-03-02
# 3      2018-01-04
# 4      2017-01-13
# 5      2018-03-04
# 6      2016-11-29
# 7      2017-07-30
# 8      2018-03-09
# 9      2017-12-08
# 10     2018-02-14
# 11     2012-08-24
# 12     2013-06-13
# 13     2017-07-11
# 14     2017-03-02
# 15     2012-04-23
# 16     2017-03-05
# 17     2017-08-29
# 18     2015-02-04
# 19     2018-02-08
# 20     2016-05-17
# 21     2015-12-08
# 22     2012-03-29
# 23     2017-05-05
# 24     2018-02-17
# 25     2012-05-03
# 26     2018-03-18
# 27     2017-10-20
# 28     2015-11-08
# 29     2015-07-09
# ...           ...
# 73831         NaT
# 73832         NaT
# 73833         NaT
# 73834         NaT
# 73835         NaT
# 73836         NaT
# 73837         NaT
# 73838         NaT
# 73839         NaT
# 73840         NaT
# 73841         NaT
# 73842         NaT
# 73843         NaT
# 73844         NaT
# 73845         NaT
# 73846         NaT
# 73847         NaT
# 73848         NaT
# 73849         NaT
# 73850         NaT
# 73851         NaT
# 73852         NaT
# 73853         NaT
# 73854         NaT
# 73855         NaT
# 73856         NaT
# 73857         NaT
# 73858         NaT
# 73859         NaT
# 73860         NaT
#
# [73861 rows x 21 columns]

# %%
engine = create_engine('sqlite:///data.db')

data.to_sql("data", con=engine, flavor="sqlite", if_exists="replace", index=False)
# Out:
# /Users/EthanCraddock/anaconda/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py:527: FutureWarning: the 'flavor' parameter is deprecated and will be removed in a future version, as 'sqlite' is the only supported option when SQLAlchemy is not installed.
#   _validate_flavor_parameter(flavor)

# %%
data.to_csv('100_test_data.csv', index=False)
